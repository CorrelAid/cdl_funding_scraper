# %%
import polars as pl

# %%
df = pl.read_parquet("troubleshooting.parquet").filter(pl.col("hits_count") != 0)

# %%
df.filter(pl.col("hits_count") == 2445)
# Out:
# shape: (0, 4)
# ┌────────────┬─────────────────┬─────────────────┬──────┐
# │ hits_count ┆ records_on_page ┆ entries         ┆ page │
# │ ---        ┆ ---             ┆ ---             ┆ ---  │
# │ i64        ┆ i64             ┆ list[struct[2]] ┆ i64  │
# ╞════════════╪═════════════════╪═════════════════╪══════╡
# └────────────┴─────────────────┴─────────────────┴──────┘

# %%
df.describe()
# Out:
# shape: (9, 5)
# ┌────────────┬─────────────┬─────────────────┬─────────┬───────────┐
# │ statistic  ┆ hits_count  ┆ records_on_page ┆ entries ┆ page      │
# │ ---        ┆ ---         ┆ ---             ┆ ---     ┆ ---       │
# │ str        ┆ f64         ┆ f64             ┆ f64     ┆ f64       │
# ╞════════════╪═════════════╪═════════════════╪═════════╪═══════════╡
# │ count      ┆ 246.0       ┆ 246.0           ┆ 246.0   ┆ 246.0     │
# │ null_count ┆ 0.0         ┆ 0.0             ┆ 0.0     ┆ 0.0       │
# │ mean       ┆ 2451.995935 ┆ 9.96748         ┆ null    ┆ 123.5     │
# │ std        ┆ 0.063758    ┆ 0.510061        ┆ null    ┆ 71.158274 │
# │ min        ┆ 2451.0      ┆ 2.0             ┆ null    ┆ 1.0       │
# │ 25%        ┆ 2452.0      ┆ 10.0            ┆ null    ┆ 62.0      │
# │ 50%        ┆ 2452.0      ┆ 10.0            ┆ null    ┆ 124.0     │
# │ 75%        ┆ 2452.0      ┆ 10.0            ┆ null    ┆ 185.0     │
# │ max        ┆ 2452.0      ┆ 10.0            ┆ null    ┆ 246.0     │
# └────────────┴─────────────┴─────────────────┴─────────┴───────────┘

# %%
df["hits_count"].value_counts()
# Out:
# shape: (2, 2)
# ┌────────────┬───────┐
# │ hits_count ┆ count │
# │ ---        ┆ ---   │
# │ i64        ┆ u32   │
# ╞════════════╪═══════╡
# │ 2452       ┆ 245   │
# │ 2451       ┆ 1     │
# └────────────┴───────┘
